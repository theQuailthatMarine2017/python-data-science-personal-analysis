# %% [markdown]
# I have loaded a dataset that contains data on School Attendance by District for Nairobi.
#
# I will try use this to improve my skills learned so far in linear regression with sklearn.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# LOAD DATASET AND EXPLORE THE GIVEN DATA!

# %%
data = pd.read_csv('School_Attendance_Data_By_District.csv')

# %%
data.head()
# Out:
#           District Rural_/_Urban Male_/_Female  \
# 0    TURKANA SOUTH         Urban          Male
# 1  NYANDARUA NORTH         Rural          Male
# 2  NYANDARUA NORTH         Rural        Female
# 3  NYANDARUA SOUTH         Rural          Male
# 4  NYANDARUA SOUTH         Rural        Female
#
#   In_school_with_pre-primary_as_percent_of_pre-primary_population  \
# 0                                                NaN
# 1                                            114.34%
# 2                                            113.68%
# 3                                             96.18%
# 4                                             93.98%
#
#   In_school_with_Primary_education_as_%_of_primary_school_age_population  \
# 0                                                NaN
# 1                                            118.51%
# 2                                            116.56%
# 3                                            120.32%
# 4                                            118.71%
# ...

# %%
new_data = data[["District","Rural_/_Urban","Male_/_Female","County","Province"]]

# %%
new_data.describe()
# Out:
#        District Rural_/_Urban Male_/_Female  County     Province
# count       632           632           632     632          632
# unique      158             2             2      47            8
# top      MASABA         Rural        Female  Kiambu  RIFT VALLEY
# freq          4           316           316      36          176

# %% [markdown]
# From the exploration above, it's easy to say most School Attendance by District was from female students, who come from rural areas mainly in Masaba District. Although it also states that on a County level Kaimbu had the highest attendance than any other county.

# %% [markdown]
# No Model can be trained from this data as no predictive assumptions can be raised.
